# %%
import numpy as np
import matplotlib.pyplot as plt
 
plt.figure(figsize=(25,12))
plt.rcParams.update({'font.size': 15})
# set width of bar
barWidth = 0.4

plt.title("Read Benchmark Plot",fontweight='bold',fontSize=40)
#our prg
bars1 = [93.59,87.648,81.687,37,36,40,14,50,53,93.59,87.648,81.687,37,36,40,14,50,53]

#iozone
bars2 = [85.43,56.418,97.662,6.708,54.691,79.382,6.852,55.016,61.906,85.425,56.418,97.662,6.708,54.691,79.382,6.852,55.016,61.906]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

 
# Make the plot
plt.bar(r1, bars1,  width=barWidth, edgecolor='white', label='My Disk BenchMark')
plt.bar(r2, bars2,  width=barWidth, edgecolor='white', label='Iozone')


plt.tick_params(axis='x', labelsize=15)
# Add xticks on the middle of the group bars
plt.xlabel('Record Size & Threads', fontweight='bold')
plt.ylabel('MB/Sec', fontweight='bold')
plt.xticks([r + (barWidth/2)  for r in range(len(bars1))], ['64KB 1','1MB 1','16MB 1','64KB 2','1MB 2','16MB 2','64KB 4','1MB 4','16MB 4','64KB 8','1MB 8','16MB 8','64KB 12','1MB 12','16MB 12','64KB 24','1MB 24','16MB 24','64KB 48','1MB 48','16MB 48'], rotation=90)
 
# Create legend & Show graphic
plt.legend()
plt.show()
